# %%
import numpy as np
import matplotlib.pyplot as plt #for displaying plots
import pandas as pd
import seaborn as sns
import tensorflow as tf
import datetime
import random
import properscoring as ps
from scipy import stats

# %%
# setting a seed to ensure reproducability and consistency
random.seed(16)
np.random.seed(16)
tf.random.set_seed(16)

# %%
df = pd.read_csv(r"C:\Users\aisti\OneDrive\Dokumente\Uni\Bachelorarbeit\Daten\bike_data_enhanced_without_lockdown_data.csv")

# %%
#save a copy of the raw data
df_raw = df.copy()

# %%
# change date column to datetime
df['date'] = pd.to_datetime(df['date'])

df.head()
# Out:
#         date  bike_count  temperature   humidity  windspeed  wind_direction  \
# 0 2012-04-25      4593.0    12.038889  65.611111   3.033333      183.333333
# 1 2012-04-26      5849.0    14.194444  66.111111   2.844444      249.444444
# 2 2012-04-27      5846.0    15.233333  68.666667   1.505556      235.000000
# 3 2012-04-28      4261.0    22.200000  53.444444   2.700000      153.888889
# 4 2012-04-29      1901.0    17.994444  62.222222   3.950000      214.444444
#
#      visibility  precipitation  sun  windspeed_max  precip_indic  precip_type  \
# 0  53611.111111            0.0  294           12.0           0.0          0.0
# 1  52555.555556            0.0  176           10.0           0.0          0.0
# 2  45055.555556            0.1  373            5.0           0.0          0.0
# 3  41500.000000            0.0  678            8.0           0.0          0.0
# 4  52777.777778            3.7  319           16.0           0.0          0.0
#
#   school_holiday  school_holiday_indicator public_holiday  \
# 0     No Holiday                         0     No Holiday
# 1     No Holiday                         0     No Holiday
# 2     No Holiday                         0     No Holiday
# 3     No Holiday                         0     No Holiday
# 4     No Holiday                         0     No Holiday
#
#    public_holiday_indicator  holiday_indicator  is_workday  season
# 0                         0                  0           1       0
# 1                         0                  0           1       0
# 2                         0                  0           1       0
# 3                         0                  0           0       0
# 4                         0                  0           0       0

# %% [markdown]
# # Dropping precip_type

# %% [markdown]
# Since the column precip_type contains some faulty values and is not expected to have a big impact on the prediction (any information contained are also represented by the temperature and precipitation columns), I will drop it.

# %%
df = df.drop('precip_type', axis=1)

# %%
df.head()
# Out:
#         date  bike_count  temperature   humidity  windspeed  wind_direction  \
# 0 2012-04-25      4593.0    12.038889  65.611111   3.033333      183.333333
# 1 2012-04-26      5849.0    14.194444  66.111111   2.844444      249.444444
# 2 2012-04-27      5846.0    15.233333  68.666667   1.505556      235.000000
# 3 2012-04-28      4261.0    22.200000  53.444444   2.700000      153.888889
# 4 2012-04-29      1901.0    17.994444  62.222222   3.950000      214.444444
#
#      visibility  precipitation  sun  windspeed_max  precip_indic  \
# 0  53611.111111            0.0  294           12.0           0.0
# 1  52555.555556            0.0  176           10.0           0.0
# 2  45055.555556            0.1  373            5.0           0.0
# 3  41500.000000            0.0  678            8.0           0.0
# 4  52777.777778            3.7  319           16.0           0.0
#
#   school_holiday  school_holiday_indicator public_holiday  \
# 0     No Holiday                         0     No Holiday
# 1     No Holiday                         0     No Holiday
# 2     No Holiday                         0     No Holiday
# 3     No Holiday                         0     No Holiday
# 4     No Holiday                         0     No Holiday
#
#    public_holiday_indicator  holiday_indicator  is_workday  season
# 0                         0                  0           1       0
# 1                         0                  0           1       0
# 2                         0                  0           1       0
# 3                         0                  0           0       0
# 4                         0                  0           0       0

# %% [markdown]
# The precip_indic column indicates wether it rained on a certain day or not. It also contains a few faulty values (caused by the aggregation of the precip_indic column from hourly to daily).
# If the precipitation is over 0 on a day, it should say 1 and 0 otherwise.

# %%
df.precip_indic.unique()
# Out:
# array([0.   , 1.   , 0.5  , 0.875, 0.75 , 0.625])

# %%
df['precip_indic'] = df['precipitation'].apply(lambda x: 1 if x > 0 else 0)

# %%
df.precip_indic.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['day_of_week'] = df['date'].dt.dayofweek

# %%
df.head()
# Out:
#         date  bike_count  temperature   humidity  windspeed  wind_direction  \
# 0 2012-04-25      4593.0    12.038889  65.611111   3.033333      183.333333
# 1 2012-04-26      5849.0    14.194444  66.111111   2.844444      249.444444
# 2 2012-04-27      5846.0    15.233333  68.666667   1.505556      235.000000
# 3 2012-04-28      4261.0    22.200000  53.444444   2.700000      153.888889
# 4 2012-04-29      1901.0    17.994444  62.222222   3.950000      214.444444
#
#      visibility  precipitation  sun  windspeed_max  precip_indic  \
# 0  53611.111111            0.0  294           12.0             0
# 1  52555.555556            0.0  176           10.0             0
# 2  45055.555556            0.1  373            5.0             1
# 3  41500.000000            0.0  678            8.0             0
# 4  52777.777778            3.7  319           16.0             1
#
#   school_holiday  school_holiday_indicator public_holiday  \
# 0     No Holiday                         0     No Holiday
# 1     No Holiday                         0     No Holiday
# 2     No Holiday                         0     No Holiday
# 3     No Holiday                         0     No Holiday
# 4     No Holiday                         0     No Holiday
#
#    public_holiday_indicator  holiday_indicator  is_workday  season  \
# 0                         0                  0           1       0
# 1                         0                  0           1       0
# 2                         0                  0           1       0
# 3                         0                  0           0       0
# 4                         0                  0           0       0
#
#    day_of_week
# 0            2
# 1            3
# 2            4
# 3            5
# 4            6

# %% [markdown]
# # Splitting the data into test set and training set
#
# The code contains data from april 2012 through january 2024. I want 2023 until january 2024 to be the test set

# %%
df.tail()
# Out:
#            date  bike_count  temperature   humidity  windspeed  \
# 3910 2024-01-21       994.0    -1.500000  87.666667   1.587500
# 3911 2024-01-22      3398.0     7.479167  76.791667   7.075000
# 3912 2024-01-23      4427.0     8.358333  74.541667   7.250000
# 3913 2024-01-24      4124.0    11.945833  72.291667   8.350000
# 3914 2024-01-25      4594.0     9.366667  85.083333   3.345833
#
#       wind_direction    visibility  precipitation  sun  windspeed_max  \
# 3910      187.500000  14942.500000            0.0  191            7.7
# 3911      223.750000  47245.416667            5.4    0           18.0
# 3912      231.250000  38257.916667            0.5  164           16.6
# 3913      234.583333  45765.833333            1.9    7           18.8
# 3914      229.583333  23374.583333            1.0  220            7.5
#
#       precip_indic school_holiday  school_holiday_indicator public_holiday  \
# 3910             0     No Holiday                         0     No Holiday
# 3911             1     No Holiday                         0     No Holiday
# 3912             1     No Holiday                         0     No Holiday
# 3913             1     No Holiday                         0     No Holiday
# 3914             1     No Holiday                         0     No Holiday
#
#       public_holiday_indicator  holiday_indicator  is_workday  season  \
# 3910                         0                  0           0       3
# 3911                         0                  0           1       3
# 3912                         0                  0           1       3
# 3913                         0                  0           1       3
# 3914                         0                  0           1       3
#
#       day_of_week
# 3910            6
# 3911            0
# 3912            1
# 3913            2
# 3914            3

# %%
filtered_df = df[['bike_count', 'temperature', 'humidity', 'windspeed', 'visibility', 'precipitation', 'sun']]

# %%
summary = filtered_df.describe()
summary
# Out:
#          bike_count  temperature     humidity    windspeed    visibility  \
# count   3915.000000  3915.000000  3915.000000  3915.000000   3915.000000
# mean    4700.835816    12.468751    73.532114     3.466377  33354.532863
# std     1922.055154     7.651280    13.795854     1.814267  16075.483974
# min      273.000000    -7.827778    31.277778     0.600000    207.777778
# 25%     3222.000000     6.397222    63.361111     2.127778  20551.111111
# 50%     4862.000000    12.411111    75.000000     3.116667  34241.666667
# 75%     6182.000000    18.669444    84.333333     4.338889  45731.666667
# max    10200.000000    31.794444   100.000000    12.233333  71937.777778
#
#        precipitation          sun
# count    3915.000000  3915.000000
# mean        1.570779   306.774457
# std         3.990632   278.571794
# min         0.000000     0.000000
# 25%         0.000000    31.000000
# 50%         0.000000   246.000000
# 75%         1.100000   545.000000
# max        58.300000   909.000000

# %%
summary_latex = summary.style.to_latex()

# %%
with open(r'C:\Users\aisti\OneDrive\Dokumente\Uni\Bachelorarbeit\Daten\summary_data.tex', 'w') as file:
    file.write(summary_latex)

# %%
df_test = df[df['date'].dt.year.isin([2023, 2024])]
df_train = df[~df['date'].dt.year.isin([2023, 2024])]

# %%
df_train.head()
# Out:
#         date  bike_count  temperature   humidity  windspeed  wind_direction  \
# 0 2012-04-25      4593.0    12.038889  65.611111   3.033333      183.333333
# 1 2012-04-26      5849.0    14.194444  66.111111   2.844444      249.444444
# 2 2012-04-27      5846.0    15.233333  68.666667   1.505556      235.000000
# 3 2012-04-28      4261.0    22.200000  53.444444   2.700000      153.888889
# 4 2012-04-29      1901.0    17.994444  62.222222   3.950000      214.444444
#
#      visibility  precipitation  sun  windspeed_max  precip_indic  \
# 0  53611.111111            0.0  294           12.0             0
# 1  52555.555556            0.0  176           10.0             0
# 2  45055.555556            0.1  373            5.0             1
# 3  41500.000000            0.0  678            8.0             0
# 4  52777.777778            3.7  319           16.0             1
#
#   school_holiday  school_holiday_indicator public_holiday  \
# 0     No Holiday                         0     No Holiday
# 1     No Holiday                         0     No Holiday
# 2     No Holiday                         0     No Holiday
# 3     No Holiday                         0     No Holiday
# 4     No Holiday                         0     No Holiday
#
#    public_holiday_indicator  holiday_indicator  is_workday  season  \
# 0                         0                  0           1       0
# 1                         0                  0           1       0
# 2                         0                  0           1       0
# 3                         0                  0           0       0
# 4                         0                  0           0       0
#
#    day_of_week
# 0            2
# 1            3
# 2            4
# 3            5
# 4            6

# %%
df_train.tail()
# Out:
#            date  bike_count  temperature   humidity  windspeed  \
# 3520 2022-12-27      2638.0     4.272222  81.777778   2.961111
# 3521 2022-12-28      2806.0     8.711111  67.166667   5.355556
# 3522 2022-12-29      2421.0    11.550000  71.777778   7.472222
# 3523 2022-12-30      2980.0     7.100000  89.388889   2.222222
# 3524 2022-12-31      2011.0    16.444444  64.500000   6.205556
#
#       wind_direction    visibility  precipitation  sun  windspeed_max  \
# 3520      212.222222  55572.777778            0.0  205            7.8
# 3521      221.666667  69854.444444            0.0   75           11.6
# 3522      221.666667  63607.777778            2.1   50           16.2
# 3523      196.111111  38045.000000            2.2  162           16.2
# 3524      218.888889  71937.777778            0.0  247           15.1
#
#       precip_indic    school_holiday  school_holiday_indicator public_holiday  \
# 3520             0  weihnachtsferien                         1     No Holiday
# 3521             0  weihnachtsferien                         1     No Holiday
# 3522             1  weihnachtsferien                         1     No Holiday
# 3523             1  weihnachtsferien                         1     No Holiday
# 3524             0  weihnachtsferien                         1     No Holiday
#
#       public_holiday_indicator  holiday_indicator  is_workday  season  \
# 3520                         0                  1           1       3
# 3521                         0                  1           1       3
# 3522                         0                  1           1       3
# 3523                         0                  1           1       3
# 3524                         0                  1           0       3
#
#       day_of_week
# 3520            1
# 3521            2
# 3522            3
# 3523            4
# 3524            5

# %%
df_test.head()
# Out:
#            date  bike_count  temperature   humidity  windspeed  \
# 3525 2023-01-01      1160.0    13.527778  66.555556   3.161111
# 3526 2023-01-02      2996.0    10.316667  79.722222   3.072222
# 3527 2023-01-03      3635.0     6.027778  88.222222   1.622222
# 3528 2023-01-04      3265.0     8.911111  77.166667   8.944444
# 3529 2023-01-05      3751.0    10.977778  81.944444   6.066667
#
#       wind_direction    visibility  precipitation  sun  windspeed_max  \
# 3525      207.777778  57907.777778            0.0  196           10.0
# 3526      204.444444  50496.666667            1.6   99           12.6
# 3527      199.444444  45582.777778            0.0  347            5.5
# 3528      227.777778  46587.777778            0.3    0           17.2
# 3529      233.333333  40345.555556            0.3   22           14.3
#
#       precip_indic    school_holiday  school_holiday_indicator public_holiday  \
# 3525             0  weihnachtsferien                         1        Neujahr
# 3526             1  weihnachtsferien                         1     No Holiday
# 3527             0  weihnachtsferien                         1     No Holiday
# 3528             1  weihnachtsferien                         1     No Holiday
# 3529             1  weihnachtsferien                         1     No Holiday
#
#       public_holiday_indicator  holiday_indicator  is_workday  season  \
# 3525                         1                  1           0       3
# 3526                         0                  1           1       3
# 3527                         0                  1           1       3
# 3528                         0                  1           1       3
# 3529                         0                  1           1       3
#
#       day_of_week
# 3525            6
# 3526            0
# 3527            1
# 3528            2
# 3529            3

# %%
df_test.tail()
# Out:
#            date  bike_count  temperature   humidity  windspeed  \
# 3910 2024-01-21       994.0    -1.500000  87.666667   1.587500
# 3911 2024-01-22      3398.0     7.479167  76.791667   7.075000
# 3912 2024-01-23      4427.0     8.358333  74.541667   7.250000
# 3913 2024-01-24      4124.0    11.945833  72.291667   8.350000
# 3914 2024-01-25      4594.0     9.366667  85.083333   3.345833
#
#       wind_direction    visibility  precipitation  sun  windspeed_max  \
# 3910      187.500000  14942.500000            0.0  191            7.7
# 3911      223.750000  47245.416667            5.4    0           18.0
# 3912      231.250000  38257.916667            0.5  164           16.6
# 3913      234.583333  45765.833333            1.9    7           18.8
# 3914      229.583333  23374.583333            1.0  220            7.5
#
#       precip_indic school_holiday  school_holiday_indicator public_holiday  \
# 3910             0     No Holiday                         0     No Holiday
# 3911             1     No Holiday                         0     No Holiday
# 3912             1     No Holiday                         0     No Holiday
# 3913             1     No Holiday                         0     No Holiday
# 3914             1     No Holiday                         0     No Holiday
#
#       public_holiday_indicator  holiday_indicator  is_workday  season  \
# 3910                         0                  0           0       3
# 3911                         0                  0           1       3
# 3912                         0                  0           1       3
# 3913                         0                  0           1       3
# 3914                         0                  0           1       3
#
#       day_of_week
# 3910            6
# 3911            0
# 3912            1
# 3913            2
# 3914            3

# %%
len(df_test)
# Out:
# 390

# %%
len(df_train)
# Out:
# 3525

# %%
df_train.to_csv(r"C:\Users\aisti\OneDrive\Dokumente\Uni\Bachelorarbeit\Daten\df_train.csv", index=False)

# %%
df_test.to_csv(r"C:\Users\aisti\OneDrive\Dokumente\Uni\Bachelorarbeit\Daten\df_test.csv", index=False)

# %%
len(df_test)
# Out:
# 390
