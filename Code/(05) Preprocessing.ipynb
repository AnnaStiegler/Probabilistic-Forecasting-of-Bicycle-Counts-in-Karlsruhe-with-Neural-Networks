# %% [markdown]
# In this notebook the data is preprocessed.

# %% [markdown]
# # Setup

# %%
import numpy as np
import matplotlib.pyplot as plt #for displaying plots
import pandas as pd
import seaborn as sns
import tensorflow as tf

from keras.layers import *
from keras.models import Sequential
from keras.models import Model
from keras.optimizers import *
from keras.callbacks import *
from keras import regularizers
from keras.utils import plot_model

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.inspection import permutation_importance
import datetime
import random
import properscoring as ps

from scipy.stats import norm

import shap
import xgboost
import pydot
import graphviz
import os
from pathlib import Path

# %%
# setting a seed to ensure reproducability and consistency
random.seed(16)
np.random.seed(16)
tf.random.set_seed(16)

# %%
# Change Working Directory
os.chdir("..")
print(os.getcwd()) # print current working directory
# Out:
# c:\Users\aisti\OneDrive\Dokumente\Uni\Bachelorarbeit\Probabilistic-Forecasting-of-Bicycle-Counts-in-Karlsruhe-with-Neural-Networks

# %%
df_train = pd.read_csv(r"data\df_train.csv")

# %%
df_test = pd.read_csv(r"data\df_test.csv")

# %%
#save a copy of the raw data
df_train_raw = df_train.copy()
df_test_raw = df_test.copy()

# %%
df_train.head()
# Out:
#          date  bike_count  temperature   humidity  windspeed  wind_direction  \
# 0  2012-04-25      4593.0    12.038889  65.611111   3.033333      183.333333
# 1  2012-04-26      5849.0    14.194444  66.111111   2.844444      249.444444
# 2  2012-04-27      5846.0    15.233333  68.666667   1.505556      235.000000
# 3  2012-04-28      4261.0    22.200000  53.444444   2.700000      153.888889
# 4  2012-04-29      1901.0    17.994444  62.222222   3.950000      214.444444
#
#      visibility  precipitation  sun  windspeed_max  precip_indic  \
# 0  53611.111111            0.0  294           12.0             0
# 1  52555.555556            0.0  176           10.0             0
# 2  45055.555556            0.1  373            5.0             1
# 3  41500.000000            0.0  678            8.0             0
# 4  52777.777778            3.7  319           16.0             1
#
#   school_holiday  school_holiday_indicator public_holiday  \
# 0     No Holiday                         0     No Holiday
# 1     No Holiday                         0     No Holiday
# 2     No Holiday                         0     No Holiday
# 3     No Holiday                         0     No Holiday
# 4     No Holiday                         0     No Holiday
#
#    public_holiday_indicator  holiday_indicator  is_workday  season  \
# 0                         0                  0           1       0
# 1                         0                  0           1       0
# 2                         0                  0           1       0
# 3                         0                  0           0       0
# 4                         0                  0           0       0
#
#    day_of_week
# 0            2
# 1            3
# 2            4
# 3            5
# 4            6

# %%
df_test.head()
# Out:
#          date  bike_count  temperature   humidity  windspeed  wind_direction  \
# 0  2023-01-01      1160.0    13.527778  66.555556   3.161111      207.777778
# 1  2023-01-02      2996.0    10.316667  79.722222   3.072222      204.444444
# 2  2023-01-03      3635.0     6.027778  88.222222   1.622222      199.444444
# 3  2023-01-04      3265.0     8.911111  77.166667   8.944444      227.777778
# 4  2023-01-05      3751.0    10.977778  81.944444   6.066667      233.333333
#
#      visibility  precipitation  sun  windspeed_max  precip_indic  \
# 0  57907.777778            0.0  196           10.0             0
# 1  50496.666667            1.6   99           12.6             1
# 2  45582.777778            0.0  347            5.5             0
# 3  46587.777778            0.3    0           17.2             1
# 4  40345.555556            0.3   22           14.3             1
#
#      school_holiday  school_holiday_indicator public_holiday  \
# 0  weihnachtsferien                         1        Neujahr
# 1  weihnachtsferien                         1     No Holiday
# 2  weihnachtsferien                         1     No Holiday
# 3  weihnachtsferien                         1     No Holiday
# 4  weihnachtsferien                         1     No Holiday
#
#    public_holiday_indicator  holiday_indicator  is_workday  season  \
# 0                         1                  1           0       3
# 1                         0                  1           1       3
# 2                         0                  1           1       3
# 3                         0                  1           1       3
# 4                         0                  1           1       3
#
#    day_of_week
# 0            6
# 1            0
# 2            1
# 3            2
# 4            3

# %%
len(df_train), len(df_test)
# Out:
# (3525, 390)

# %% [markdown]
# # Preprocessing

# %%
scaler = StandardScaler()

# %%
def preproc(df_in, fit_scaler, col_normalize = ['temperature', 'humidity', 'windspeed', 'wind_direction', 'visibility', 'precipitation', 'sun', 'windspeed_max' ] ):
    df = df_in.copy()
   
    #Split features and targets
    y = df.pop('bike_count') if 'bike_count' in df.columns else None
    X = df
    
    #normalize values
    if fit_scaler:
        X[col_normalize] = scaler.fit_transform(X[col_normalize]) #only normalize columns with numerical and non categorical values
    else:
        X[col_normalize] = scaler.transform(X[col_normalize]) #only normalize columns with numerical and non categorical values
    
    X['date'] =  pd.to_datetime(X['date'])
        
    X_num = df.select_dtypes(include=['number'])
    
   

    return X, y, X_num

# %%
split_date_valid = '2022-01-01'

# %%
X_train, y_train, X_train_num = preproc(df_train[df_train.date <= split_date_valid], True)

# %%
X_valid, y_valid, X_valid_num = preproc(df_train[df_train.date > split_date_valid], False)

# %%
X_test, y_test, X_test_num = preproc(df_test, False)

# %%
#reset indices, so every dataset starts at 0
X_train = X_train.reset_index(drop=True)
X_train_num = X_train_num.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)

X_valid = X_valid.reset_index(drop=True)
X_valid_num = X_valid_num.reset_index(drop=True)
y_valid = y_valid.reset_index(drop=True)

X_test = X_test.reset_index(drop=True)
X_test_num = X_test_num.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
y_test.iloc[5]
# Out:
# 1574.0

# %%
X_test.iloc[365]
# Out:
# date                        2024-01-01 00:00:00
# temperature                           -0.573209
# humidity                                -0.2248
# windspeed                              2.236176
# wind_direction                         0.649639
# visibility                             1.281107
# precipitation                         -0.397192
# sun                                   -0.859681
# windspeed_max                          1.688415
# precip_indic                                  0
# school_holiday                 weihnachtsferien
# school_holiday_indicator                      1
# public_holiday                          Neujahr
# public_holiday_indicator                      1
# holiday_indicator                             1
# is_workday                                    0
# season                                        3
# day_of_week                                   0
# Name: 365, dtype: object

# %% [markdown]
# ## Checking the Data

# %%
X_train.shape, X_valid.shape, X_test.shape
# Out:
# ((3161, 18), (364, 18), (390, 18))

# %%
X_train_num.shape, X_valid_num.shape, X_test_num.shape
# Out:
# ((3161, 15), (364, 15), (390, 15))

# %%
y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((3161,), (364,), (390,))

# %%
X_train.head()
# Out:
#         date  temperature  humidity  windspeed  wind_direction  visibility  \
# 0 2012-04-25    -0.039776 -0.645081  -0.218119        0.079113    1.461434
# 1 2012-04-26     0.244625 -0.607815  -0.324284        1.042128    1.392951
# 2 2012-04-27     0.381694 -0.417343  -1.076810        0.831722    0.906360
# 3 2012-04-28     1.300863 -1.551894  -0.405469       -0.349793    0.675680
# 4 2012-04-29     0.745990 -0.897664   0.297096        0.532297    1.407369
#
#    precipitation       sun  windspeed_max  precip_indic school_holiday  \
# 0      -0.397192 -0.031329       0.665623             0     No Holiday
# 1      -0.397192 -0.458165       0.154228             0     No Holiday
# 2      -0.371451  0.254435      -1.124262             1     No Holiday
# 3      -0.397192  1.357699      -0.357168             0     No Holiday
# 4       0.555250  0.059103       1.688415             1     No Holiday
#
#    school_holiday_indicator public_holiday  public_holiday_indicator  \
# 0                         0     No Holiday                         0
# 1                         0     No Holiday                         0
# 2                         0     No Holiday                         0
# 3                         0     No Holiday                         0
# 4                         0     No Holiday                         0
#
#    holiday_indicator  is_workday  season  day_of_week
# 0                  0           1       0            2
# 1                  0           1       0            3
# 2                  0           1       0            4
# 3                  0           0       0            5
# 4                  0           0       0            6

# %%
y_train.head()
# Out:
# 0    4593.0
# 1    5849.0
# 2    5846.0
# 3    4261.0
# 4    1901.0
# Name: bike_count, dtype: float64

# %%
X_train_num.head()
# Out:
#    temperature  humidity  windspeed  wind_direction  visibility  \
# 0    -0.039776 -0.645081  -0.218119        0.079113    1.461434
# 1     0.244625 -0.607815  -0.324284        1.042128    1.392951
# 2     0.381694 -0.417343  -1.076810        0.831722    0.906360
# 3     1.300863 -1.551894  -0.405469       -0.349793    0.675680
# 4     0.745990 -0.897664   0.297096        0.532297    1.407369
#
#    precipitation       sun  windspeed_max  precip_indic  \
# 0      -0.397192 -0.031329       0.665623             0
# 1      -0.397192 -0.458165       0.154228             0
# 2      -0.371451  0.254435      -1.124262             1
# 3      -0.397192  1.357699      -0.357168             0
# 4       0.555250  0.059103       1.688415             1
#
#    school_holiday_indicator  public_holiday_indicator  holiday_indicator  \
# 0                         0                         0                  0
# 1                         0                         0                  0
# 2                         0                         0                  0
# 3                         0                         0                  0
# 4                         0                         0                  0
#
#    is_workday  season  day_of_week
# 0           1       0            2
# 1           1       0            3
# 2           1       0            4
# 3           0       0            5
# 4           0       0            6

# %%
X_train.describe()
# Out:
#                                 date   temperature      humidity  \
# count                           3161  3.161000e+03  3.161000e+03
# mean   2016-10-06 22:22:03.378677504  4.450726e-16 -3.281849e-16
# min              2012-04-25 00:00:00 -2.660948e+00 -3.112937e+00
# 25%              2014-06-24 00:00:00 -7.932892e-01 -7.651612e-01
# 50%              2016-08-22 00:00:00 -9.270793e-04  9.610389e-02
# 75%              2018-11-02 00:00:00  7.907021e-01  7.793190e-01
# max              2022-01-01 00:00:00  2.566737e+00  1.918011e+00
# std                              NaN  1.000158e+00  1.000158e+00
#
#           windspeed  wind_direction    visibility  precipitation  \
# count  3.161000e+03    3.161000e+03  3.161000e+03   3.161000e+03
# mean   4.832859e-17    1.719599e-16 -1.078964e-16   3.708939e-17
# min   -1.513961e+00   -2.348657e+00 -2.003308e+00  -3.971923e-01
# 25%   -7.364558e-01   -6.573103e-01 -8.238480e-01  -3.971923e-01
# 50%   -2.056287e-01    4.432786e-01  3.399334e-02  -3.971923e-01
# 75%    4.969366e-01    7.507961e-01  7.585809e-01  -1.140338e-01
# max    4.952762e+00    2.361217e+00  2.407294e+00   1.461021e+01
# std    1.000158e+00    1.000158e+00  1.000158e+00   1.000158e+00
#
#                 sun  windspeed_max  precip_indic  school_holiday_indicator  \
# count  3.161000e+03   3.161000e+03   3161.000000               3161.000000
# mean   4.720467e-17  -1.185736e-16      0.401772                  0.232521
# min   -1.094803e+00  -1.891355e+00      0.000000                  0.000000
# 25%   -9.899026e-01  -6.384357e-01      0.000000                  0.000000
# 50%   -2.085744e-01  -1.014702e-01      0.000000                  0.000000
# 75%    8.585175e-01   5.122046e-01      1.000000                  0.000000
# max    2.193287e+00   5.523883e+00      1.000000                  1.000000
# std    1.000158e+00   1.000158e+00      0.490334                  0.422506
#
#        public_holiday_indicator  holiday_indicator   is_workday       season  \
# count               3161.000000        3161.000000  3161.000000  3161.000000
# mean                   0.033534           0.248972     0.684910     1.492249
# min                    0.000000           0.000000     0.000000     0.000000
# 25%                    0.000000           0.000000     0.000000     1.000000
# 50%                    0.000000           0.000000     1.000000     1.000000
# 75%                    0.000000           0.000000     1.000000     2.000000
# max                    1.000000           1.000000     1.000000     3.000000
# std                    0.180054           0.432486     0.464625     1.101504
#
#        day_of_week
# count  3161.000000
# mean      3.001898
# min       0.000000
# 25%       1.000000
# 50%       3.000000
# 75%       5.000000
# max       6.000000
# std       2.001106

# %% [markdown]
# ## Saving the Data

# %%
def conv_to_csv(df, filename):
    complete_filename = r"data\\" + filename + ".csv"
    df.to_csv(complete_filename, index=False)

# %%
def conv_to_pickle(df, filename):
    complete_filename = r"data\\" + filename + ".pkl"
    df.to_pickle(complete_filename)

# %%
conv_to_csv(X_train, "X_train")
conv_to_csv(X_valid, "X_valid")
conv_to_csv(X_test, "X_test")

conv_to_csv(y_train, "y_train")
conv_to_csv(y_valid, "y_valid")
conv_to_csv(y_test, "y_test")

conv_to_csv(X_train_num, "X_train_num")
conv_to_csv(X_valid_num, "X_valid_num")
conv_to_csv(X_test_num, "X_test_num")

# %%
conv_to_pickle(X_train, "X_train")
conv_to_pickle(X_valid, "X_valid")
conv_to_pickle(X_test, "X_test")

conv_to_pickle(y_train, "y_train")
conv_to_pickle(y_valid, "y_valid")
conv_to_pickle(y_test, "y_test")

conv_to_pickle(X_train_num, "X_train_num")
conv_to_pickle(X_valid_num, "X_valid_num")
conv_to_pickle(X_test_num, "X_test_num")
